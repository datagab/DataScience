# %% [markdown]
# # Surprising Leicester City 2015/2016 season

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/pt/0/07/Logo_Premier_League_2016_2017_1.jpg)
#
# The Premier League 15/16 season was a wonder with a unlikely champion and giants falling for behind. Claudio Ranieri's squad and the likes of Kanté, Vardy and Mahrez enchanted the world beating the odds and winning the trophy.
#
# ![](https://d3nfwcxd527z59.cloudfront.net/content/uploads/2017/07/19101731/Leicester-City-Premier-League-title-2015-16.jpg)
#
# **As a football fan and an aspiring data scientist, I will analyse it following the according plan:**
#
# * Web Scraping the season table
# * How did they let us win? (EDA and Data Visualization)

# %% [markdown]
# ## **Web Scraping(season table and players stats)**

# %% [markdown]
# The first step is to get all the necessary data from web via web scraping. For such activity, we have to make a HTTP request for the url and get its status code. Any code starting with 2..(200,201...) means success.

# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests # http requests
from bs4 import BeautifulSoup #Manipulating HTML
import re #regular expressions
import csv #Manipulating csv files

# %%
#Defining website to request
base_url = 'https://www.skysports.com/premier-league-table/2015'
page = requests.get(base_url) #Making the request
page.status_code
# Out:
# 200

# %% [markdown]
# Now we have our content in our variable called page.

# %%
page.text

# %% [markdown]
# Did you get it? I didn't.
# <br/>To make our page content better looking, we're going to use the library called BeautifulSoup.
# We're going to parse the html and make it prettier.

# %%
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Premier League Table &amp; Standings - Sky Sports Football
#   </title>
#   <meta content="NOODP,INDEX,FOLLOW" name="robots">
#    <meta content="Complete table of Premier League standings for the 2015/2016 Season, plus access to tables from past seasons and other Football leagues." name="description"/>
#    <meta content="Sky, Sports, Football, News, Premier, League, Fixtures, Results, Tables, Photos, Transfer, Centre, Arsenal, Aston Villa, Birmingham City, Blackburn Rovers, Bolton Wanderers, Burnley, Chelsea, Everton, Fulham, Hull City, Liverpool, Manchester City, Man City, Manchester United, Man Utd, Portsmouth, Stoke City, Sunderland, Tottenham Hotspur, Spurs, West Ham, Wigan Athletic, Wolverhampton Wanderers, Wolves, watch, video, live, pc. torress, benitez" name="keywords"/>
#    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#    <link href="//e0.365dm.com" rel="dns-prefetch"/>
#    <link href="//e1.365dm.com" rel="dns-prefetch"/>
#    <link href="//e2.365dm.com" rel="dns-prefetch"/>
#    <link href="//fresh8.co" rel="dns-prefetch"/>
#    <link href="//annex.fresh8.co" rel="dns-prefetch"/>
#    <link href="//cdn-gs.fresh8.co" rel="dns-prefetch"/>
#    <link href="//player.ooyala.com" rel="dns-prefetch"/>
#    <link href="//static.chartbeat.com" rel="dns-prefetch"/>
#    <link href="//assets.adobedtm.com" rel="dns-prefetch"/>
#    <link href="//img.skysports.com" rel="dns-prefetch"/>
#    <link href="//video.skysports.com" rel="dns-prefetch"/>
#    <link href="//cdn.livefyre.com" rel="dns-prefetch"/>
#    <link href="//app-cdn.spot.im" rel="dns-prefetch"/>
#    <link href="//cdn.teads.tv" rel="dns-prefetch"/>
#    <link href="//services.babator.com" rel="dns-prefetch"/>
#    <link href="//eu-services.babator.com" rel="dns-prefetch"/>
#    <link href="//widgets.oddschecker.com" rel="dns-prefetch"/>
#    <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="//metrics-api.librato.com" rel="dns-prefetch"/>
#    <link href="//cloud-static.storage.googleapis.com" rel="dns-prefetch"/>
#    <link href="//analytics.ooyala.com" rel="dns-prefetch"/>
#    <link href="//l.ooyala.com" rel="dns-prefetch"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <meta content="Sky Sports" name="apple-mobile-web-app-title"/>
#    <meta content="SkySports" name="application-name"/>
#    <meta content="width=device-width,maximum-scale=1,minimum-scale=1,minimal-ui" id="viewport" name="viewport"/>
#    <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <meta content="GeOj3ib0hXB5Iewz4HWUfve0FidZUHpPXlBi6oPOTjU" name="google-site-verification">
#     <meta content="10911153761" property="fb:pages">
#      <meta content="509247152,100000206570823" property="fb:admins">
#       <meta content="Premier League (Sky Sports)" property="og:title">
#        <meta content="https://www.skysports.com/premier-league-table/2015" property="og:url">
#         <meta content="Get the latest Premier League Football news, fixtures, results, video and more from Sky Sports." property="og:description">
#          <meta content="SkySports" property="og:site_name">
#           <script>
#            if ((/iPad|iPhone|iPod/).test(navigator.userAgent)) {
#     var headNode = document.getElementsByTagName('head')[0];
#     var sbNode = document.createElement('meta');
#     sbNode.name = 'apple-itunes-app';
#     sbNode.content = 'app-id=500102120';
#     headNode.appendChild(sbNode);
# }
#           </script>
#           <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon">
#            <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed">
#             <style data-webfont-src="/static/skytext-reg-bce1c746d381a.css">
#             </style>
#             <style data-webfont-src="/static/skytext-med-c849e3d033da4.css">
#             </style>
#             <style data-webfont-src="/static/skycons-baae5a5793309.css">
#             </style>
#             <link href="/static/skysports-digrev-9b93c0efa829c.css" media="all" rel="stylesheet" title="default" type="text/css">
#              <!--[if IE 8]>
#         <link rel="stylesheet" type="text/css" href="/static/skysports-digrev-ie8-e9f0525acf687.css">
#     <![endif]-->
#              <script data-grade-b-src="/static/head-grade-b-6a22e81a4779c.js" data-grade-c-src="/static/head-grade-c-a4c5458d881fc.js" id="script-polyfills">
#              </script>
#              <script>
#               // google ads set up
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.adSlots = {};
#              </script>
#              <script type="text/javascript">
#               var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.uid = '43610';
#       _sf_async_config.domain = 'skysports.com';
#       _sf_async_config.flickerControl = false;
#       _sf_async_config.useCanonical = true;
#              </script>
#              <script>
#               window.SKY_SPORTS = window.SKY_SPORTS || {
#     deferedFunctionsCalled: !1,
#     deferredArray: [],
#     deferred: function(e) {
#         this.deferredArray.push(e);
#     },
#     callDeferredFunctions: function() {
#         if (!this.deferedFunctionsCalled) {
#             for (var e = -1; ++e < this.deferredArray.length; ) this.deferredArray[e] && this.deferredArray[e].call();
#             this.deferedFunctionsCalled = !0;
#         }
#     },
#     initIframeWidget: function(t) {
#         window.addEventListener("message", function(e) {
#             t.style.height = e.data + "px";
#         });
#     }
# }, function() {
#     window.aab = window.aab || {}, aab.playerLoaded = function(y) {
#         y = y || "OO", aab.playerLoadedCalled = y, window[y].aabPluginLoaded || window[y].plugin("AAB", function(S, e, t, n) {
#             aab.addingPlugin = !0, aab.OO = S;
#             return function(t, e) {
#                 var i, a, n, o, r, s, d = !(window[y].aabPluginLoaded = !0), c = !1, l = 3e4, u = 1e3;
#                 function m() {
#                     var e = new Date().getTime();
#                     o = o || e, d || (null == n || S.supportsFlash) && (c && !r || (!s && n.error && f(0, n.error),
#                     l < e - o ? p() : setTimeout(m, u)));
#                 }
#                 function p() {
#                     function e() {
#                         var e = document.createElement("div");
#                         e.style.height = "100%", e.style.backgroundColor = "#000", e.style.color = "#999",
#                         e.style.textAlign = "center", e.innerHTML = "<br><br>An error occurred when loading the player.<br>Please review your connection settings and try again.",
#                         document.getElementById(i).innerHTML = "", document.getElementById(i).appendChild(e);
#                     }
#                     n.destroy(), t.subscribe(S.EVENTS.DESTROY, "aab", e), e();
#                 }
#                 function f(e, t) {
#                     s = t && "cannotDownloadThirdPartyModule" === t.code && "flash" === t.source;
#                 }
#                 function h() {
#                     d = !0;
#                     var a = console.error;
#                     console.error = function() {
#                         a.apply || Function.prototype.apply.apply(a, [ console, arguments ]), a.apply(console, arguments);
#                         var e = arguments && 0 < arguments.length ? arguments[0] : "";
#                         if (e.match(/Error\: Ad adLoadError/i)) {
#                             var t = document.getElementById(i).getElementsByTagName("object"), n = null;
#                             t && (1 == t.length ? n = t[0] : 2 == t.length && (n = t[1])), n && (e.match(/errorCode\: 1001/i) ? n.adLoadEmptyVast && n.adLoadEmptyVast() : n.adLoadError && n.adLoadError());
#                         }
#                     };
#                 }
#                 function w() {
#                     !n && S.supportsFlash && (n = S.players[i]) && (t.subscribe("aabLoaded", "aab", h),
#                     t.subscribe("aabBlocked", "aab", p), t.subscribe("preDetectionComplete", "aab", function() {}),
#                     t.subscribe("noAdBlockerDetected", "aab", function() {}), t.subscribe("adBlockerDetected", "aab", function() {}),
#                     setTimeout(m, u));
#                 }
#                 S.supportsFlash && (t.subscribe(S.EVENTS.PLAYER_CREATED, "aab", function(e, t, n) {
#                     i = t, a = n;
#                 }), t.subscribe(S.EVENTS.PLAYER_EMBEDDED, "aab", w), t.subscribe(S.EVENTS.METADATA_FETCHED, "aab", function(e, t) {
#                     for (var n in w(), c = !0, r = !!t.base.aabEnabled && "true" === t.base.aabEnabled,
#                     function() {
#                         if (!r) {
#                             var e = "anti-adblocker";
#                             a.devModuleURL && a.devModuleURL.toLowerCase().indexOf("aabadsmanager.swf") && (e = "dev-other"),
#                             a[e] && a[e].aab && a[e].aab.aabEnabled && (r = !0);
#                         }
#                     }(), t.modules) ;
#                 }), t.subscribe(S.EVENTS.ERROR, "aab", f));
#             };
#         });
#     };
#     var n = [ "OO", "OoyalaPlayer1", "OoyalaPlayer2", "OoyalaPlayer3", "OoyalaPlayer4", "OoyalaPlayer5", "OoyalaPlayer6", "OoyalaPlayer7", "OoyalaPlayer8" ];
#     function e() {
#         aab.onReadyCalled = !0;
#         for (var e = 0; e < n.length; e++) {
#             var t = n[e];
#             if (window[t]) {
#                 aab.namespaceFound = t, aab.playerLoaded(t);
#                 break;
#             }
#         }
#     }
#     document.addEventListener ? (aab.eventListenerType = "addEventListener", document.addEventListener("DOMContentLoaded", e)) : document.attachEvent && (aab.eventListenerType = "attachEvent",
#     aab.onreadystatechangeFired = !1, document.attachEvent("onreadystatechange", function() {
#         aab.onreadystatechangeFired = !0, "complete" === document.readyState && (document.detachEvent("onreadystatechange", arguments.callee),
#         e());
#     })), e();
# }(), function() {
#     for (var i = 0, e = [ "moz", "webkit" ], t = 0; t < e.length && !window.requestAnimationFrame; ++t) window.requestAnimationFrame = window[e[t] + "RequestAnimationFrame"],
#     window.cancelAnimationFrame = window[e[t] + "CancelAnimationFrame"] || window[e[t] + "CancelRequestAnimationFrame"];
#     window.requestAnimationFrame || (window.requestAnimationFrame = function(e) {
#         var t = new Date().getTime(), n = Math.max(0, 16 - (t - i)), a = window.setTimeout(function() {
#             e(t + n);
#         }, n);
#         return i = t + n, a;
#     }), window.cancelAnimationFrame || (window.cancelAnimationFrame = function(e) {
#         clearTimeout(e);
#     });
# }(), function() {
#     var e = document.createElement("div");
#     e.setAttribute("data-a", "b"), e.className = "a";
#     var t = document.getElementById("script-polyfills");
#     t && ("addEventListener" in window && Function.prototype.bind && String.prototype.trim && "textContent" in e && Array.prototype.indexOf || document.write("<script src='" + t.getAttribute("data-grade-c-src") + "'><\/script>"),
#     "classList" in e && "dataset" in e || document.write("<script src='" + t.getAttribute("data-grade-b-src") + "'><\/script>"));
# }(), SKY_SPORTS.getUa = function(t) {
#     function e(e) {
#         return !!t.match(e) && parseFloat(t.match(e)[1].replace("_", "."));
#     }
#     var n = !1;
#     null !== new RegExp("MSIE ([0-9]{1,}[.0-9]{0,})").exec(t) && (n = parseFloat(RegExp.$1));
#     var a = t.match(/iPad/), i = t.match(/iP/), o = t.match(/android/i), r = t.match(/windows phone/i), s = navigator.platform.match(/mac|win/i), d = {
#         classList: ""
#     };
#     return r && ((d = {
#         mobile: !0,
#         windowsphone: !0,
#         name: "windowsphone",
#         version: e(/os ([0-9]\.[0-9])/i) || e(/windows phone ([0-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), n && ((d = {
#         msie: !0,
#         name: "msie",
#         version: n
#     }).classList = [ d.name, d.name + d.version ].join(" ")), (a || i) && ((d = {
#         ios: !0,
#         name: a ? "ipad" : "iphone",
#         mobile: !0,
#         version: e(/os ([1-9]\_[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, d.device, "ios", "ios" + d.version, "mobile" ].join(" ")),
#     o && ((d = {
#         android: !0,
#         name: "android",
#         mobile: !0,
#         version: e(/android ([1-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), s && (d.desktop = !0,
#     d.classList += " desktop"), d;
# }, SKY_SPORTS.getFeatures = function(n, e) {
#     function t(e, t) {
#         return n.classList += t ? " " + e : " no-" + e, t;
#     }
#     e.style.cssText = "-webkit-animation-name:shim;animation-name:shim;-moz-animation-name:shim;width:10vw",
#     n.hasTouch = t("touch", "ontouchstart" in window || "DocumentTouch" in window && document instanceof window.DocumentTouch),
#     n.hasSvg = t("svg", !!document.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#BasicStructure", "1.1")),
#     n.hasCssAnimations = t("cssanimations", !!(e.style.animationName || e.style.webkitAnimationName || e.style.mozAnimationName)),
#     n.hasVpUnits = t("vpunits", !!e.style.width), n.hasWebWorkers = t("web-workers", !!window.Worker);
#     var a = {
#         webkitAnimation: "webkitAnimationStart",
#         mozAnimation: "mozAnimationStart",
#         animation: "animationstart",
#         msAnimation: "MSAnimationStart"
#     };
#     for (var i in a) i in e.style && (n.animationEventName = a[i]);
#     return n;
# }, SKY_SPORTS.device = SKY_SPORTS.getUa(navigator.userAgent), SKY_SPORTS.getFeatures(SKY_SPORTS.device, document.createElement("div")),
# document.documentElement.className = "js " + SKY_SPORTS.device.classList, function(t, e) {
#     t.SKY_SPORTS = t.SKY_SPORTS || {}, localStorage.removeItem("jscss");
#     var n = e.createElement("style"), a = "ss.js.styles", i = {}, o = t.localStorage.getItem(a);
#     function r() {
#         var e = function() {
#             var e = "";
#             for (var t in i) e += i[t];
#             return e;
#         }();
#         n.styleSheet ? n.styleSheet.cssText = e : n.textContent = e, t.localStorage.setItem(a, JSON.stringify(i));
#     }
#     n.id = a, e.getElementsByTagName("head")[0].appendChild(n), o && (i = JSON.parse(o)),
#     r(), t.SKY_SPORTS.addCss = function(e) {
#         e.id in i != 0 && i[e.id] === e.css || (i[e.id] = e.css), r();
#     }, t.SKY_SPORTS.removeCss = function(e) {
#         e in i && delete i[e], r();
#     };
# }(window, document), function(r) {
#     function s(e, t) {
#         t.match("font-family: 'SkyTextMed'") && (t += t.replace("font-family: 'SkyTextMed'", "font-weight: 600; font-family: 'skytext'")),
#         t.match("font-family: 'SkyTextReg'") && (t += t.replace("font-family: 'SkyTextReg'", "font-weight: 400; font-family: 'skytext'")),
#         e.styleSheet ? e.styleSheet.cssText = t : e.textContent = t;
#     }
#     SKY_SPORTS.getFont = function(t, e) {
#         if ("keys" in Object != !1) {
#             var n, a;
#             n = e.split("/").pop(), (a = n.split("-")).splice(-1), a = a.join("-");
#             var i = r.localStorage.getItem(n);
#             if (i) s(t, i); else {
#                 Object.keys(r.localStorage).forEach(function(e) {
#                     e.match(a) && r.localStorage.removeItem(e);
#                 });
#                 var o = new XMLHttpRequest();
#                 o.onreadystatechange = function() {
#                     if (4 === this.readyState && 200 === this.status) {
#                         var e = this.responseText;
#                         s(t, e), r.localStorage.setItem(n, e);
#                     }
#                 }, o.open("GET", e, !0), o.send();
#             }
#         }
#     };
#     for (var e = document.querySelectorAll("style[data-webfont-src]"), t = -1; ++t < e.length; ) SKY_SPORTS.getFont(e[t], e[t].getAttribute("data-webfont-src"));
# }(window), function(t, n) {
#     "use strict";
#     if (n.currentBreakPoint = 10, n.currentAdvertBreakPoint = "display", n.getBreakPoint = function() {
#         var e = t.getComputedStyle(n.body, ":after").getPropertyValue("content");
#         return e = parseInt(e.replace(/['"]/g, ""), 10);
#     }, n.getAdvertBreakPoint = function() {
#         return t.getComputedStyle(n.body, ":before").getPropertyValue("content").replace(/['"]/g, "");
#     }, Function.prototype.debounce = function(e) {
#         var t = this;
#         return function() {
#             t.args = arguments, t.timeout_id && clearTimeout(t.timeout_id), t.timeout_id = setTimeout(function() {
#                 return t.apply(t, t.args);
#             }, e);
#         };
#     }, n.createEvent) {
#         var a = n.createEvent("Event");
#         a.initEvent("breakPointChange", !0, !0);
#         var i = n.createEvent("Event");
#         i.initEvent("advertChange", !0, !0), t.addEventListener("DOMContentLoaded", function() {
#             n.currentBreakPoint = n.getBreakPoint(), n.currentAdvertBreakPoint = n.getAdvertBreakPoint();
#         }, !1), t.addEventListener("resize", function() {
#             var e = n.getBreakPoint(), t = n.getAdvertBreakPoint();
#             e !== n.currentBreakPoint && (n.currentBreakPoint = e, n.dispatchEvent(a)), t !== n.currentAdvertBreakPoint && (n.currentAdvertBreakPoint = t,
#             n.dispatchEvent(i));
#         }.debounce(300), !1);
#     }
# }(window, document), function() {
#     function s(e) {
#         for (var t = document.cookie.split(";"), n = -1; ++n < t.length; ) {
#             var a = t[n].split("=");
#             if (a[0].match(e)) return decodeURIComponent(a[1]);
#         }
#         return "";
#     }
#     function d() {
#         var e = window.SKY_SPORTS.user;
#         return e.isLoggedIn ? e.isSkySports ? 1 : e.isWholesale ? 3 : 4 : 2;
#     }
#     window.SKY_SPORTS = window.SKY_SPORTS || {}, function e() {
#         var t, n, a = s("interactive"), i = a ? JSON.parse(a) : {}, o = s("skySportsSSO"), r = {
#             isLoggedIn: (t = o, !!t),
#             getType: d,
#             set: e
#         };
#         r.isLoggedIn && (r.name = i.f || "", r.isSkyHD = 1 === i.hd, r.isSky = 1 === i.st,
#         r.isSkySports = 2 === i.st, r.isNowTV = 3 === i.st, r.isWholesale = !(!(n = o) || !n.match(/^WIG/))),
#         window.SKY_SPORTS.user = r, function(e) {
#             var t = e.getType(), n = 1 === t || 3 === t ? '.item[data-role="nosub"]{display:none!important}.item[data-role="sub"]{display:inline-block!important}' : '.item[data-role="sub"] {display:none!important}';
#             n += 1 !== t || e.isWholesale ? "" : ".remote-record-link.-hdn {display:block!important}";
#             var a = e.isWholesale ? "[data-not-for-wholesale]{display:none!important}" : "";
#             window.SKY_SPORTS.addCss({
#                 id: "userTypeButton",
#                 css: '.button[data-role="subscriber-promo-button"]:after{content:attr(data-usertype' + t + ")}" + n + a
#             }), window.SKY_SPORTS.addCss({
#                 id: "userLabel",
#                 css: ".user-label:after{content:attr(data-label-type" + t + ")}"
#             });
#         }(window.SKY_SPORTS.user);
#     }();
# }(), SKY_SPORTS.postpone = {
#     funcs: {},
#     init: function() {
#         this.items = document.getElementsByClassName("postpone"), this.addFunc("removeclass", function() {
#             var e = this.getAttribute("data-postpone-removeclass");
#             e && this.classList.remove(e), this.classList.remove("postpone");
#         }), this.scan();
#     },
#     addFunc: function(e, t) {
#         this.funcs[e] = t;
#     },
#     scan: function() {
#         for (var e = -1; ++e < this.items.length; ) {
#             var t, n = this.items[e];
#             n.whenVisible || (t = n.getAttribute("data-postpone-call")) && this.funcs[t] && (n.whenVisible = this.funcs[t],
#             n.setAttribute("data-postpone-class", this.className), n.detach = this.detach),
#             this.isInViewPort(n) && n.whenVisible();
#         }
#         var a = this;
#         setTimeout(function() {
#             window.requestAnimationFrame(a.scan.bind(a));
#         }, 50);
#     },
#     isInViewPort: function(e) {
#         var t = e.getBoundingClientRect();
#         return 0 !== t.width && (!(t.bottom < 0) && !(window.innerHeight - t.top < 0));
#     }
# }, SKY_SPORTS.postpone.init();
#              </script>
#              <script src="//assets.adobedtm.com/ea8b05805335bbbe5843bc504517194c8ae74941/satelliteLib-61b6d7ab6fe000db0802bf9147e2b52574ae3bc5.js">
#              </script>
#              <script src="https://www.skysports.com/sourcepoint/script/cmp_shim.js">
#              </script>
#              <script>
#               window._sp_ = window._sp_ || {};
#     window._sp_.config = window._sp_.config || {};
#
#     // Config:
#     window._sp_.config.account_id = 630;
#     window._sp_.config.mms_domain = 'mms.cmpsky.com';
#     window._sp_.config.runImmediately = true;
#
#     // messaging-specific configuration
#     window._sp_.mms = window._sp_.mms || {};
#     window._sp_.mms.cmd = window._sp_.mms.cmd || [];
#     //CMP Flags
#     window._sp_.config.cmp = _sp_.config.cmp || {};
#     window._sp_.config.cmp.enabled = true;
#     window._sp_.config.writeFirstPartyCookies = true;
#     //Have message show immediately
#     window._sp_.config.detection = window._sp_.config.detection || {};
#     window._sp_.config.detection.timeout = 1;
#     //Code to call the server and display a message
#     window._sp_.mms.cmd.push( function () {
#         window._sp_.mms.startMsg();
#     });
#              </script>
#              <script src="https://www.skysports.com/sourcepoint/script/messages.js">
#              </script>
#              <script type="text/javascript">
#               __cmp('getConsentData', null, function (e) {});
#              </script>
#              <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#              </script>
#             </link>
#            </link>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="site-header site-header--rainbow">
#    <div class="site-header__body">
#     <div class="site-header__col site-header__col1">
#      <a class="svg-logo site-header__logo" href="https://www.skysports.com">
#       <img class="svg-logo__image" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'" src="/core/img/channels/Sky-Sports-Logo-transparent.svg"/>
#      </a>
#     </div>
#     <div class="site-header__col site-header__col2">
#      <div class="site-login callfn" data-fn="skyid-login" data-lite="true">
#       <script class="login-text" data-role="default" type="text/template">
#        <!--default-->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><a class="site-login__link site-login__link--user callfn" href="https://skyid.sky.com/signin/sports?successUrl=https%3A%2F%2Fwww.skysports.com%2Fpremier-league-table%2F2015" data-mobile-url="/sso/signin/mobile" data-desktop-url="/sso/signin/desktop" data-lite="true" >Log In</a></li>
#                 </ul>
#       </script>
#       <script class="login-text" data-role="isSkySports" type="text/template">
#        <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2015" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#       </script>
#       <script class="login-text" data-role="isSky" type="text/template">
#        <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo">
#                         <a href="/watch/get-sky" class="site-login__link">Upgrade</a>
#                     </li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2015" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#       </script>
#       <script class="login-text" data-role="isNowTv" type="text/template">
#        <!-- now tv customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2015" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#       </script>
#       <script class="login-text" data-role="isLoggedIn" type="text/template">
#        <!-- just a sky id login -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2015" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#       </script>
#       <script class="login-text" data-role="isWholesale" type="text/template">
#        <!-- wholesale customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user"></span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2015" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#       </script>
#      </div>
#     </div>
#     <div class="site-header__col site-header__col3">
#      <form action="https://www.skysports.com/search" class="site-search" method="GET">
#       <input accesskey="q" autocapitalize="off" autocomplete="off" autocorrect="off" class="site-search__input" name="q" placeholder="Search Sky Sports" type="text"/>
#       <input name="searchtype" type="hidden" value="the site"/>
#       <input name="v" type="hidden" value="2"/>
#       <button class="site-search__button">
#        <span class="site-search__button-label">
#         Search
#        </span>
#       </button>
#      </form>
#     </div>
#     <a class="site-header__col site-header__col4 site-header__nav-button-hit-area" data-role="open-left-hand-nav" href="#no-js-nav" tabindex="1">
#      <svg class="site-header__nav-button" version="1.1" viewbox="0 0 2048 2048" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <rect height="256" width="2048" y="384">
#       </rect>
#       <rect height="256" width="2048" y="896">
#       </rect>
#       <rect height="256" width="2048" y="1408">
#       </rect>
#      </svg>
#     </a>
#    </div>
#    <!-- desktop nav -->
#    <div aria-hidden="true" class="site-nav-desktop__wrap adaptive-content callfn" data-fn="adaptive-content" data-lite="true">
#     <script type="text/template">
#      <div class="site-nav-desktop callfn" role="navigation" data-fn="site-nav-desktop" data-lite="true">
# <ul class="site-nav-desktop__body">
# <li class="site-nav-desktop__item">
# <a href="/" class="site-nav-desktop__item-link">
# Home</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-sports-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-sports-more-nav" id="site-nav-desktop-sports-more">
# Sports</a>
# <div class="site-nav-desktop__menu" aria-labelledby="site-nav-desktop-sports-more" id="site-nav-desktop-sports-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football">
# Football</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/f1">
# F1</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/cricket">
# Cricket</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-union">
# Rugby Union</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-league">
# Rugby League</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/golf">
# Golf</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/boxing">
# Boxing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/tennis">
# Tennis</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/cycling">
# Cycling</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/racing">
# Racing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/darts">
# Darts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nfl">
# NFL</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nba">
# NBA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/motorsport">
# Motorsport</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/netball">
# Netball</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/gaa">
# GAA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/wwe">
# WWE</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mma">
# MMA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/esports">
# eSports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/more-sports">
# More Sports</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/live-scores" class="site-nav-desktop__item-link">
# Score Centre</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch/video" class="site-nav-desktop__item-link">
# Video</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch" class="site-nav-desktop__item-link">
# TV</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="https://www.skybet.com?aff=9749&dcmp=ss_main_nav" class="site-nav-desktop__item-link" target="_blank">
# Sky Bet</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/games" class="site-nav-desktop__item-link">
# Games</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-more-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-more-more-nav" id="site-nav-desktop-more-more">
# More</a>
# <div class="site-nav-desktop__menu site-nav-desktop__menu--right" aria-labelledby="site-nav-desktop-more-more" id="site-nav-desktop-more-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/transfer-centre">
# Transfer Centre</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/sport-on-sky">
# Live on Sky</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/get-sky?dcmp=gss_more_dropdown">
# Get Sky Sports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-shows">
# TV Shows</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-guide">
# TV Guide</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/competitions">
# Competitions</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/shop/tv/sky-go/?dcmp=skygo_ss.com_more" target="_blank">
# Sky Go</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_moredropdownlink" target="_blank">
# Now TV</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://pubfinder.sky.com/" target="_blank">
# Pub Finder</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-shows/sportswomen">
# Sportswomen</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/scholarships">
# Sports Scholarships</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football/news/topic/7964/tackling-racism">
# Tackling Racism</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/podcasts">
# Podcasts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mobile">
# Mobile</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://twitter.com/SkySports" target="_blank">
# Twitter</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.facebook.com/SkySports" target="_blank">
# Facebook</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/contact-us">
# Contact Us</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" target="_blank">
# Terms &amp; Conditions</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# <a href="https://www.skysports.com/watch" class="site-nav-desktop__watch-button no-default-hover no-default-active"><span class="site-nav-desktop__watch-button__label">Watch Sky Sports</span></a>
# </div>
#     </script>
#    </div>
#   </div>
#   <div id="mobile-bet-basket">
#   </div>
#   <div class="advert--banner-wrap-ghost">
#    <div class="advert--banner-wrap">
#     <div class="block advert advert--banner">
#      <div class="advert__container" id="leaderboard">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="site-wrapper">
#    <div class="grid site-layout-primary callfn" data-fn="site-layout-primary" data-lite="true">
#     <div class="grid__col site-layout-primary__col1">
#      <!-- page title -->
#      <div class="page-header">
#       <ul class="page-header__breadcrumb">
#        <li class="page-header__breadcrumb-item">
#         <h2 class="page-header__breadcrumb-title">
#          <a class="page-header__breadcrumb-link" href="https://www.skysports.com/football">
#           Football
#          </a>
#         </h2>
#        </li>
#       </ul>
#       <h1 class="page-header__title">
#        <a class="page-header__title-link" href="/premier-league">
#         <abbr class="swap-text--bp30" title="Premier League">
#          <span class="swap-text__target">
#           Premier League
#          </span>
#         </abbr>
#        </a>
#        <span class="page-header__title-subitem">
#         Table
#        </span>
#       </h1>
#       <div class="block page-header__sponsor">
#        <div class="advert__container" id="sponsor-position">
#        </div>
#       </div>
#      </div>
#      <div class="page-nav callfn" data-fn="page-nav" data-lite="true">
#       <a aria-controls="page-nav-control" class="page-nav__head" href="#page-nav" id="page-nav-control">
#        <h3 class="page-nav__title">
#         Table
#        </h3>
#        <div class="page-nav__title-more">
#        </div>
#       </a>
#       <div class="page-nav__frame">
#        <div aria-labelledby="page-nav" class="page-nav__body" id="page-nav" style=" visibility: hidden;">
#         <ul class="page-nav__item-group">
#          <li class="page-nav__item">
#           <a class="page-nav__link" href="/premier-league-news">
#            News
#           </a>
#          </li>
#          <li class="page-nav__item page-nav__item--select">
#           <select class="page-nav__select callfn" data-fn="implicit-personalisation-display" data-key="football.team" data-label="Your most viewed" data-lite="true" data-name="skysports-implicit-personalisation" onchange="location.href=this.options[selectedIndex].value" tabindex="-1">
#            <option disabled="" selected="selected">
#             Select a team
#            </option>
#            <option class="page-nav__select-option" id="all-teams" value="/football/teams">
#             All Teams
#            </option>
#            <optgroup label="Premier League">
#             <option class="page-nav__select-option" data-itemid="413" value="/arsenal">
#              Arsenal
#             </option>
#             <option class="page-nav__select-option" data-itemid="238" value="/aston-villa">
#              Aston Villa
#             </option>
#             <option class="page-nav__select-option" data-itemid="333" value="/bournemouth">
#              Bournemouth
#             </option>
#             <option class="page-nav__select-option" data-itemid="212" value="/brighton-and-hove-albion">
#              Brighton
#             </option>
#             <option class="page-nav__select-option" data-itemid="160" value="/burnley">
#              Burnley
#             </option>
#             <option class="page-nav__select-option" data-itemid="524" value="/chelsea">
#              Chelsea
#             </option>
#             <option class="page-nav__select-option" data-itemid="234" value="/crystal-palace">
#              Crystal Palace
#             </option>
#             <option class="page-nav__select-option" data-itemid="229" value="/everton">
#              Everton
#             </option>
#             <option class="page-nav__select-option" data-itemid="152" value="/leicester-city">
#              Leicester City
#             </option>
#             <option class="page-nav__select-option" data-itemid="155" value="/liverpool">
#              Liverpool
#             </option>
#             <option class="page-nav__select-option" data-itemid="345" value="/manchester-city">
#              Manchester City
#             </option>
#             <option class="page-nav__select-option" data-itemid="210" value="/manchester-united">
#              Manchester United
#             </option>
#             <option class="page-nav__select-option" data-itemid="409" value="/newcastle-united">
#              Newcastle United
#             </option>
#             <option class="page-nav__select-option" data-itemid="290" value="/norwich-city">
#              Norwich City
#             </option>
#             <option class="page-nav__select-option" data-itemid="444" value="/sheffield-united">
#              Sheffield United
#             </option>
#             <option class="page-nav__select-option" data-itemid="392" value="/southampton">
#              Southampton
#             </option>
#             <option class="page-nav__select-option" data-itemid="608" value="/tottenham-hotspur">
#              Tottenham Hotspur
#             </option>
#             <option class="page-nav__select-option" data-itemid="508" value="/watford">
#              Watford
#             </option>
#             <option class="page-nav__select-option" data-itemid="367" value="/west-ham-united">
#              West Ham United
#             </option>
#             <option class="page-nav__select-option" data-itemid="206" value="/wolverhampton-wanderers">
#              Wolverhampton
#             </option>
#            </optgroup>
#            <optgroup label="Championship">
#             <option class="page-nav__select-option" data-itemid="191" value="/barnsley">
#              Barnsley
#             </option>
#             <option class="page-nav__select-option" data-itemid="247" value="/birmingham-city">
#              Birmingham City
#             </option>
#             <option class="page-nav__select-option" data-itemid="262" value="/blackburn-rovers">
#              Blackburn Rovers
#             </option>
#             <option class="page-nav__select-option" data-itemid="194" value="/brentford">
#              Brentford
#             </option>
#             <option class="page-nav__select-option" data-itemid="236" value="/bristol-city">
#              Bristol City
#             </option>
#             <option class="page-nav__select-option" data-itemid="202" value="/cardiff-city">
#              Cardiff City
#             </option>
#             <option class="page-nav__select-option" data-itemid="154" value="/charlton-athletic">
#              Charlton Athletic
#             </option>
#             <option class="page-nav__select-option" data-itemid="295" value="/derby-county">
#              Derby County
#             </option>
#             <option class="page-nav__select-option" data-itemid="407" value="/fulham">
#              Fulham
#             </option>
#             <option class="page-nav__select-option" data-itemid="422" value="/huddersfield-town">
#              Huddersfield Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="253" value="/hull-city">
#              Hull City
#             </option>
#             <option class="page-nav__select-option" data-itemid="183" value="/leeds-united">
#              Leeds United
#             </option>
#             <option class="page-nav__select-option" data-itemid="226" value="/luton-town">
#              Luton Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="389" value="/middlesbrough">
#              Middlesbrough
#             </option>
#             <option class="page-nav__select-option" data-itemid="704" value="/millwall">
#              Millwall
#             </option>
#             <option class="page-nav__select-option" data-itemid="522" value="/nottingham-forest">
#              Nottingham Forest
#             </option>
#             <option class="page-nav__select-option" data-itemid="436" value="/preston-north-end">
#              Preston North End
#             </option>
#             <option class="page-nav__select-option" data-itemid="411" value="/queens-park-rangers">
#              Queens Park Rangers
#             </option>
#             <option class="page-nav__select-option" data-itemid="216" value="/reading">
#              Reading
#             </option>
#             <option class="page-nav__select-option" data-itemid="376" value="/sheffield-wednesday">
#              Sheffield Wednesday
#             </option>
#             <option class="page-nav__select-option" data-itemid="384" value="/stoke-city">
#              Stoke City
#             </option>
#             <option class="page-nav__select-option" data-itemid="375" value="/swansea-city">
#              Swansea City
#             </option>
#             <option class="page-nav__select-option" data-itemid="275" value="/west-bromwich-albion">
#              West Bromwich Albion
#             </option>
#             <option class="page-nav__select-option" data-itemid="457" value="/wigan-athletic">
#              Wigan Athletic
#             </option>
#            </optgroup>
#            <optgroup label="League One">
#             <option class="page-nav__select-option" data-itemid="579" value="/accrington-stanley">
#              Accrington Stanley
#             </option>
#             <option class="page-nav__select-option" data-itemid="419" value="/afc-wimbledon">
#              AFC Wimbledon
#             </option>
#             <option class="page-nav__select-option" data-itemid="231" value="/blackpool">
#              Blackpool
#             </option>
#             <option class="page-nav__select-option" data-itemid="555" value="/bolton-wanderers">
#              Bolton Wanderers
#             </option>
#             <option class="page-nav__select-option" data-itemid="282" value="/bristol-rovers">
#              Bristol Rovers
#             </option>
#             <option class="page-nav__select-option" data-itemid="294" value="/burton-albion">
#              Burton Albion
#             </option>
#             <option class="page-nav__select-option" data-itemid="156" value="/bury">
#              Bury
#             </option>
#             <option class="page-nav__select-option" data-itemid="571" value="/coventry-city">
#              Coventry City
#             </option>
#             <option class="page-nav__select-option" data-itemid="397" value="/doncaster-rovers">
#              Doncaster
#             </option>
#             <option class="page-nav__select-option" data-itemid="230" value="/fleetwood-town">
#              Fleetwood Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="356" value="/gillingham">
#              Gillingham
#             </option>
#             <option class="page-nav__select-option" data-itemid="157" value="/ipswich-town">
#              Ipswich Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="181" value="/lincolncity">
#              Lincoln City
#             </option>
#             <option class="page-nav__select-option" data-itemid="423" value="/milton-keynes-dons">
#              Milton Keynes Dons
#             </option>
#             <option class="page-nav__select-option" data-itemid="638" value="/oxford-united">
#              Oxford United
#             </option>
#             <option class="page-nav__select-option" data-itemid="630" value="/peterborough-united">
#              Peterborough United
#             </option>
#             <option class="page-nav__select-option" data-itemid="298" value="/portsmouth">
#              Portsmouth
#             </option>
#             <option class="page-nav__select-option" data-itemid="425" value="/rochdale">
#              Rochdale
#             </option>
#             <option class="page-nav__select-option" data-itemid="441" value="/rotherham-united">
#              Rotherham United
#             </option>
#             <option class="page-nav__select-option" data-itemid="773" value="/shrewsbury-town">
#              Shrewsbury Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="765" value="/southend-united">
#              Southend United
#             </option>
#             <option class="page-nav__select-option" data-itemid="415" value="/sunderland">
#              Sunderland
#             </option>
#             <option class="page-nav__select-option" data-itemid="196" value="/tranmere-rovers">
#              Tranmere Rovers
#             </option>
#             <option class="page-nav__select-option" data-itemid="421" value="/wycombe-wanderers">
#              Wycombe Wanderers
#             </option>
#            </optgroup>
#            <optgroup label="League Two">
#             <option class="page-nav__select-option" data-itemid="448" value="/bradford-city">
#              Bradford City
#             </option>
#             <option class="page-nav__select-option" data-itemid="442" value="/cambridge-united">
#              Cambridge United
#             </option>
#             <option class="page-nav__select-option" data-itemid="179" value="/carlisle-united">
#              Carlisle United
#             </option>
#             <option class="page-nav__select-option" data-itemid="534" value="/cheltenham-town">
#              Cheltenham Town
#             </option>
#             <option class="page-nav__select-option" data-itemid="293" value="/colchester-united">
#              Colchester United
#             </option>
# ...
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://www.planetf1.com" target="_blank">
#           Planet F1
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://www.cricket365.com/" target="_blank">
#           Cricket365
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="site-footer__col accordian__item" id="site-footer-channels-group&gt;">
#       <a aria-controls="site-footer-channels" class="site-footer__head accordian__item-head" href="#" id="site-footer-channels">
#        Sky Sports Channels
#       </a>
#       <div aria-labelledby="site-footer-channels" class="accordian__item-content-frame" id="site-footer-channels-nav">
#        <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-main-event">
#           Sky Sports Main Event
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-premier-league">
#           Sky Sports Premier League
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-football">
#           Sky Sports Football
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-cricket">
#           Sky Sports Cricket
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-golf">
#           Sky Sports Golf
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-racing">
#           Sky Sports Racing
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-f1">
#           Sky Sports F1
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-action">
#           Sky Sports Action
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-arena">
#           Sky Sports Arena
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-news">
#           Sky Sports News
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="/watch/sky-sports-mix">
#           Sky Sports Mix
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="site-footer__col accordian__item" id="site-footer-sky-sites-group&gt;">
#       <a aria-controls="site-footer-sky-sites" class="site-footer__head accordian__item-head" href="#" id="site-footer-sky-sites">
#        More Sky Sites
#       </a>
#       <div aria-labelledby="site-footer-sky-sites" class="accordian__item-content-frame" id="site-footer-sky-sites-nav">
#        <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://www.sky.com/" target="_blank">
#           Sky.com
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://news.sky.com/" target="_blank">
#           Sky News
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://www.skygroup.sky/corporate" target="_blank">
#           Sky Corporate
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://business.sky.com/" target="_blank">
#           Sky For Businesses
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_footer" target="_blank">
#           Now TV
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://communaltv.sky.com/" target="_blank">
#           Sky Communal TV
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://www.skyacademy.com/" target="_blank">
#           Sky Academy
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://www.skygroup.sky/corporate/bigger-picture" target="_blank">
#           Bigger Picture
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://www.sky.com/shop/store-locator/" target="_blank">
#           Store Locator
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="http://www.workforsky.com/" target="_blank">
#           Work for Sky
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://www.skymedia.co.uk/?utm_source=Sky_Sports&amp;utm_medium=Web_page&amp;utm_content=Sky_Sports_web_page&amp;utm_campaign=Sky_Sports_web_page" target="_blank">
#           Advertise With Us
#          </a>
#         </li>
#         <li class="site-footer__item">
#          <a class="site-footer__link" href="https://accessories.sky.com/" target="_blank">
#           Sky TV Accessories
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#     </ul>
#     <!-- / LINKS GRID -->
#     <ul class="site-footer__nav site-footer__nav--horizontal-nav">
#      <li class="site-footer__item site-footer__item--inline">
#       <a class="site-footer__link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" target="_blank">
#        Terms &amp; Conditions
#       </a>
#      </li>
#      <li class="site-footer__item site-footer__item--inline">
#       <a class="site-footer__link" href="https://www.sky.com/help/articles/sky-privacy-and-cookies-notice" target="_blank">
#        Privacy &amp; Cookies Notice
#       </a>
#      </li>
#      <li class="site-footer__item site-footer__item--inline">
#       <a class="site-footer__link" href="#privacy-options">
#        Privacy Options
#       </a>
#      </li>
#      <li class="site-footer__item site-footer__item--inline">
#       <a class="site-footer__link" href="http://accessibility.sky.com/" target="_blank">
#        Accessibility Information
#       </a>
#      </li>
#      <li class="site-footer__item site-footer__item--inline">
#       <a class="site-footer__link" href="/contact-us">
#        Contact Us
#       </a>
#      </li>
#     </ul>
#     <p class="site-footer__copyright">
#      <a class="svg-logo site-footer__site-logo" href="https://www.skysports.com">
#       <img class="svg-logo__image" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'" src="/core/img/channels/Sky-Sports-Logo.svg"/>
#      </a>
#      ©2019 Sky UK
#     </p>
#    </div>
#   </div>
#   <div class="callfn" data-campaign-id="2370" data-component-name="sdc-site-consent-management" data-fn="sdc-site-consent-management" data-lite="true" data-privacy-manager-id="5be44b558258ec45a3975501" data-selector=".site-footer a[href='#privacy-options']">
#   </div>
#   <!-- / SITE FOOTER -->
#   <script src="/static/require-2.1.0-15f03d8ff7a4b.js">
#   </script>
#   <script src="/static/include-2612c20a957a859745b30e18986ce54a-84cb184bdb1d0.js">
#   </script>
#   <script>
#    require.config({"shim":{"facebook-sdk":{"exports":"FB"}},"baseUrl":"/","paths":{"skysports_com":"static/skysports_com-b3fbffb5f0195","skysports_digrev":"static/skysports_digrev-f17b87f0f7c8f","skysports_legacy":"static/skysports_legacy-e7dde831a4d39","skysports_ipad_components":"static/skysports_ipad_components-4798d45d25479","skysports_sap":"core/js/../static/js/skysports_sap","requireLib":"static/require-2.1.0-15f03d8ff7a4b","class":"static/class-55bbf080a62c3","countdown":"static/countdown-3c7569426f127","energize":"static/energize-bac53226fb-9795bcfacb255","hammer":"static/hammer-a592776ebb-f14662ea8bb34","marker-clusterer":"static/marker-clusterer-8a934d664ede6","moment":"static/moment-1.7.2-33075cfd4ad32","reqwest":"static/reqwest-a845dfd832-dea6ebed2de7d","scroll-pane":"static/ftscroller-280c6900bc-ca9da74da3fb9","underscore":"static/lodash.custom-80970c5a1825d","adaptive-content":"static/adaptive-content-1fc383fae518a","article-widget-betting":"static/article-widget-betting-7a9641160b027","app-bridge":"static/app-bridge-30b975666386a","article-advert":"static/article-advert-fa40febcc7b0f","article-outbrain":"static/article-outbrain-d353f1cf3f851","autocomplete":"static/autocomplete-62886d6993248","autocomplete-lite":"static/autocomplete-lite-c397d58384aeb","accordian":"static/accordian-87ec71ccbfdd1","betting-lines":"static/betting-lines-31e5cdbecf2bc","bskyb-omniture":"static/bskyb-omniture-de3e9caef9fce","bskyb-omniture-1-2":"static/bskyb-omniture-1.2-ef8627d226d42","calendar-url-builder":"static/calendar-url-builder-863fca999d8c8","carousel":"static/carousel-cfdab6400e999","carousel-lite":"static/carousel-lite-520eccc372b67","close-me":"static/close-me-1dd5bf41462eb","content-stream":"static/content-stream-4ceef3bbd096b","content-swap":"static/content-swap-bdbe29a70d8f9","countdown-widget":"static/countdown-widget-459a93f477481","comments-reply":"static/comments-reply-81d5853bdd03b","cookie":"static/cookie-072824b3a5047","android-notice":"static/android-notice-58d95f174579a","create-audio":"static/create-audio-f77436036a203","create-video":"static/create-video-f5fe547b889be","create-video2":"static/create-video2-bb132ac918d30","dataset":"static/dataset-487d6875fe94d","datepicker":"static/datepicker-b112a28bd151b","datepicker2":"static/datepicker2-d10188465db39","dom":"static/dom-f554c2354ab77","dropdown":"static/dropdown-de4729ed67884","dropdown-select":"static/dropdown-select-bbaa962ff8888","edigital-survey":"static/edigital-survey-6.0.6.0-13762d4026255","element-listener":"static/element-listener-39391d1341a3c","environment":"static/environment-d24a016d1c736","events":"static/events-e6bde13ac56dc","facebook-sdk":"//connect.facebook.net/en_US/all","fastclick":"static/fastclick-ea596eafa5-1c2edee75a004","form":"static/form-269f9f014d35a","form-chart":"static/form-chart-8e3b2b92c7e77","form-validation":"static/form-validation-76d631ee9c0fb","html-poller":"static/html-poller-db12e18d06d04","implicit-personalisation-display":"static/implicit-personalisation-display-2bc93246729e4","implicit-personalisation-storage":"static/implicit-personalisation-storage-a4eb341b47077","implicit-personalisation-removal":"static/implicit-personalisation-removal-7556598e29ff5","inverted-listener":"static/inverted-listener-07a7ace73331d","iscroll-lite":"static/iscroll-lite-03ad473f62d1a","keyboard-listener":"static/keyboard-listener-f6b30a391df5b","keyboard-view":"static/keyboard-view-5a68be0e6dc00","lazy-images":"static/lazy-images-f5238f2864a52","live-article":"static/live-article-95ba706f060b3","live-cricket":"static/live-cricket-98d8debeb2633","live-sport":"static/live-sport-77265bd8792ec","live-update":"static/live-update-945d95543ad61","live-refresh":"static/live-refresh-5ebefb5206c82","live-refresh-darts-table-controller":"static/live-refresh-darts-table-controller-d6c7bb8af0efe","live-refresh-darts-table-view":"static/live-refresh-darts-table-view-5c4f5e87a3cb2","live-refresh-football-controller":"static/live-refresh-football-c ...
#
#         require(['skysports_digrev', 'sdc-site-pub-sub'], function (appController, pubsub) {
#             window.sdc = window.sdc || {};
#             pubsub.init(window.sdc);
#
#             appController.init();
#         });
#   </script>
#   <!-- eDigital Survey Code -->
#   <iframe id="ecos_iframe" src="javascript:'';" style="position:absolute; left: 0; top: 0; width: 1px; height: 1px; visibility: hidden;" title="">
#   </iframe>
#   <iframe id="ecos_iframe2" src="javascript:'';" style="position:absolute; left: 0; top: 0; width: 1px; height: 1px; visibility: hidden;" title="">
#   </iframe>
#   <div id="ecos_surveylayer" style="position:absolute; left: 0; top: 0; width: 1px; height: 1px; visibility: hidden;" title="Visitor Survey (dynamically generated)">
#   </div>
#   <script src="/static/edigital-survey-6.0.6.0-1df4c88b99dc3.js" type="text/javascript">
#   </script>
#   <noscript>
#    <img alt="" border="0" height="1" src="https://ecustomeropinions.com/survey/img.php?sid=588330148&amp;nojs=1" width="1">
#     <a href="https://ecustomeropinions.com/survey/noscript.php?sid=588330148&amp;nojs=1&amp;vlt=_" rel="nofollow">
#      We would like your feedback, please fill in our survey
#     </a>
#    </img>
#   </noscript>
#   <!-- eDigital Survey Code End -->
#   <script src="/static/require-2.1.0-15f03d8ff7a4b.js" type="text/javascript">
#   </script>
#   <script>
#    SKY_SPORTS.deferred(function () {
#
#     var st_tag = document.createElement('script');
#     st_tag.async = true;
#     st_tag.src = "//native.sharethrough.com/assets/tag.js";
#     document.getElementsByTagName('head')[0].appendChild(st_tag);
#
# });
#   </script>
#   <script async="" src="https://cloud-static.storage.googleapis.com/production/widgets/mk2/js/common/generator.min.js">
#   </script>
#   <script type="text/javascript">
#    window.ocEnv={url:window.location.href,};
#   </script>
#   <script>
#    SKY_SPORTS.deferred(function(){
#         require(['bskyb-omniture'], function (bskybOmniture) {
#
#             var aamGetCookie =  function (c_name)
#             {
#                 var i, x, y, c = document.cookie.split(";");
#                 for (i = 0; i < c.length; i++)
#                 {
#                     x = c[i].substr(0, c[i].indexOf("="));
#                     y = c[i].substr(c[i].indexOf("=") + 1);
#                     x = x.replace(/^\s+|\s+$/g, "");
#                     if (x == c_name)
#                     {
#                         return unescape(y);
#                     }
#                 }
#             };
#
#             var tracking = '';
#             var cookie = aamGetCookie("interactive");
#             var interactive = (cookie) ? JSON.parse(cookie) : {};
#             if( 'undefined' !== typeof interactive.tid ) {
#                 tracking = interactive.tid;
#             }
#
#             var omnitureInitiated = false;
#
#             var initAnalytics = function(targetData) {
#
#                 if(omnitureInitiated) {
#                     return;
#                 }
#
#                 omnitureInitiated = true;
#
#                 var omnitureData = {
#                     trackingId: tracking,
#                     site: "sky/portal/sports",
#                     section: "football/barclays_premier_league",
#                     contentType: "table",
#                                         contentId: "",
#                     sport: "Football",                    account: "bskybsports,bskybnetworkglobal"
#                 };
#
#
#                 if(typeof targetData !== "undefined" && targetData.tntVal) {
#                     omnitureData.tnt = targetData.tntVal;
#                 }
#
#                 // site-wide analytics
#                 bskybOmniture.init(omnitureData);
#             };
#
#             if(window.sdc && window.sdc.pubSub) {
#                 window.sdc.pubSub.subscribe('dynamic-tile.events.adobe-target-fetched', function(data) {
#                     initAnalytics(data);
#                 });
#             }
#
#             setTimeout(initAnalytics, 2000);
#
#         });
#     });
#
#     var s_account = "bskybsports,bskybnetworkglobal";
#   </script>
#   <script type="text/javascript">
#    _satellite.pageBottom();
#   </script>
#   <script>
#    var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.sections = 'type:table,premier league,football';
#
#
#     window._sf_endpt = new Date().getTime();
#     var script = document.createElement('script');
#     script.src = document.location.protocol + '//static.chartbeat.com/js/chartbeat.js';
#     document.body.appendChild(script);
#   </script>
#  </body>
# </html>

# %% [markdown]
# We have the full html of the page now but we're only interested to scrape the season table from it.
# <br/>Using the .find() method, we're looking for a table body tag.
# We're turning it into string because we're going to manipulate it later.

# %%
tables = str(soup.find("tbody"))
tables
# Out:
# '<tbody>\n<tr class="standing-table__row" data-item-id="152">\n<td class="standing-table__cell">1</td>\n<td class="standing-table__cell standing-table__cell--name" data-long-name="Leicester City" data-short-name="Leicester City">\n<a class="standing-table__cell--name-link" href="/leicester-city">Leicester City</a>\n</td>\n<td class="standing-table__cell">38</td>\n<td class="standing-table__cell is-hidden--bp35">23</td>\n<td class="standing-table__cell is-hidden--bp35">12</td>\n<td class="standing-table__cell is-hidden--bp35">3</td>\n<td class="standing-table__cell is-hidden--bp35">68</td>\n<td class="standing-table__cell is-hidden--bp35">36</td>\n<td class="standing-table__cell">32</td>\n<td class="standing-table__cell" data-sort-value="1">81</td>\n<td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">\n</td>\n</tr>\n<tr class="standing-table__row" data-item-id="413">\n<td class="standing-table__cell">2</td>\n<td class="standing-table__cell standing-table__cell--name" data-long-name="Arsenal" data-short-name="Arsenal">\n<a class="standing-table__cell--name-link" href="/arsenal">Arsenal</a>\n</td>\n<td class="standing-table__cell">38</td>\n<td class="standing-table__cell is-hidden--bp35">20</td>\n<td class="standing-table__cell is-hidden--bp35">11</td>\n<td class="standing-table__cell is-hidden--bp35">7</td>\n<td class="standing-table__cell is-hidden--bp35">65</td>\n<td class="standing-table__cell is-hidden--bp35">36</td>\n<td class="standing-table__cell">29</td>\n<td class="standing-table__cell" data-sort-value="2">71</td>\n<td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">\n</td>\n</tr>\n<tr class="standing-table__row" data-item-id="608">\n<td class="standing-table__cell">3</td>\n<td class="standing-table__cell standing-table__cell--name" data-long-name="Tottenham Hotspur" data-short-name="Tottenham Hotspur">\n<a class="standing-table__cell--name-link" href="/tottenham-hotspur">Tottenham Hotspur</a>\n</td>\n<td class="standing-table__cell">38</td>\n<td class="standing-table__cell is-hidden--bp35">19</td>\n<td class="standing-table__cell is-hidden--bp35">13</td>\n<td class="standing-table__cell is-hidden--bp35">6</td>\n<td class="standing-table__cell is-hidden--bp35">69</td>\n<td class="standing-table__cell is-hidden--bp35">35</td>\n<td class="standing-table__cell">34</td>\n<td class="standing-table__cell" data-sort-value="3">70</td>\n<td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">\n</td>\n</tr>\n<tr class="standing-table__row" data-item-id="345">\n<td class="standing-table__cell">4</td>\n<td class="standing-table__cell standing-table__cell--name" data-long-name="Manchester City" data-short-name="Manchester City">\n<a class="standing-table__cell--name-link" href="/manchester-city">Manchester City</a>\n</td>\n<td class="standing-table__cell">38</td>\n<td class="standing-table__cell is-hidden--bp35">19</td>\n<td class="standing-table__cell is-hidden--bp35">9</td>\n<td class="standing-table__cell is-hidden--bp35">10</td>\n<td class="standing-table__cell is-hidden--bp35">71</td>\n<td class="standing-table__cell is-hidden--bp35">41</td>\n<td class="standing-table__cell">30</td>\n<td class="standing-table__cell" data-sort-value="4">66</td>\n<td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">\n</td>\n</tr>\n<tr class="standing-table__row standing-table__row--divider" data-item-id="210">\n<td class="standing-table__cell">5</td>\n<td class="standing-table__cell standing-table__cell--name" data-long-name="Manchester United" data-short-name="Manchester United">\n<a class="standing-table__cell--name-link" href="/manchester-united">Manchester United</a>\n</td>\n<td class="standing-table__cell">38</td>\n<td class="standing-table__cell is-hidden--bp35">19</td>\n<td class="standing-table__cell is-hidden--bp35">9</td>\n<td class="standing-table__cell is-hidden--bp35">1 ...

# %% [markdown]
# It's looking confusing again but we can already notice the data we want such as the club names and their respective positions.
# <br/>Using the regular expression (re) library, we're about the stripe all the html tags.

# %%
cleanr = re.compile('<.*?>')
cleantext = re.sub(cleanr, '', tables)
cleantext
# Out:
# '\n\n1\n\nLeicester City\n\n38\n23\n12\n3\n68\n36\n32\n81\n\n\n\n\n2\n\nArsenal\n\n38\n20\n11\n7\n65\n36\n29\n71\n\n\n\n\n3\n\nTottenham Hotspur\n\n38\n19\n13\n6\n69\n35\n34\n70\n\n\n\n\n4\n\nManchester City\n\n38\n19\n9\n10\n71\n41\n30\n66\n\n\n\n\n5\n\nManchester United\n\n38\n19\n9\n10\n49\n35\n14\n66\n\n\n\n\n6\n\nSouthampton\n\n38\n18\n9\n11\n59\n41\n18\n63\n\n\n\n\n7\n\nWest Ham United\n\n38\n16\n14\n8\n65\n51\n14\n62\n\n\n\n\n8\n\nLiverpool\n\n38\n16\n12\n10\n63\n50\n13\n60\n\n\n\n\n9\n\nStoke City\n\n38\n14\n9\n15\n41\n55\n-14\n51\n\n\n\n\n10\n\nChelsea\n\n38\n12\n14\n12\n59\n53\n6\n50\n\n\n\n\n11\n\nEverton\n\n38\n11\n14\n13\n59\n55\n4\n47\n\n\n\n\n12\n\nSwansea City\n\n38\n12\n11\n15\n42\n52\n-10\n47\n\n\n\n\n13\n\nWatford\n\n38\n12\n9\n17\n40\n50\n-10\n45\n\n\n\n\n14\n\nWest Bromwich Albion\n\n38\n10\n13\n15\n34\n48\n-14\n43\n\n\n\n\n15\n\nCrystal Palace\n\n38\n11\n9\n18\n39\n51\n-12\n42\n\n\n\n\n16\n\nBournemouth\n\n38\n11\n9\n18\n45\n67\n-22\n42\n\n\n\n\n17\n\nSunderland\n\n38\n9\n12\n17\n48\n62\n-14\n39\n\n\n\n\n18\n\nNewcastle United\n\n38\n9\n10\n19\n44\n65\n-21\n37\n\n\n\n\n19\n\nNorwich City\n\n38\n9\n7\n22\n39\n67\n-28\n34\n\n\n\n\n20\n\nAston Villa\n\n38\n3\n8\n27\n27\n76\n-49\n17\n\n\n\n'

# %% [markdown]
# Better but still not what we want, more additional data cleaning

# %%
cleantext2 = list(cleantext.split("\n"))
cleantext2
# Out:
# ['',
#  '',
#  '1',
#  '',
#  'Leicester City',
#  '',
#  '38',
#  '23',
#  '12',
#  '3',
#  '68',
#  '36',
#  '32',
#  '81',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  'Arsenal',
#  '',
#  '38',
#  '20',
#  '11',
#  '7',
#  '65',
#  '36',
#  '29',
#  '71',
#  '',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  'Tottenham Hotspur',
#  '',
#  '38',
#  '19',
#  '13',
#  '6',
#  '69',
#  '35',
#  '34',
#  '70',
#  '',
#  '',
#  '',
#  '',
#  '4',
#  '',
#  'Manchester City',
#  '',
#  '38',
#  '19',
#  '9',
#  '10',
#  '71',
#  '41',
#  '30',
#  '66',
#  '',
#  '',
#  '',
#  '',
#  '5',
#  '',
#  'Manchester United',
#  '',
#  '38',
#  '19',
#  '9',
#  '10',
#  '49',
#  '35',
#  '14',
#  '66',
#  '',
#  '',
#  '',
#  '',
#  '6',
#  '',
#  'Southampton',
#  '',
#  '38',
#  '18',
#  '9',
#  '11',
#  '59',
#  '41',
#  '18',
#  '63',
#  '',
#  '',
#  '',
#  '',
#  '7',
#  '',
#  'West Ham United',
#  '',
#  '38',
#  '16',
#  '14',
#  '8',
#  '65',
#  '51',
#  '14',
#  '62',
#  '',
#  '',
#  '',
#  '',
#  '8',
#  '',
#  'Liverpool',
#  '',
#  '38',
#  '16',
#  '12',
#  '10',
#  '63',
#  '50',
#  '13',
#  '60',
#  '',
#  '',
#  '',
#  '',
#  '9',
#  '',
#  'Stoke City',
#  '',
#  '38',
#  '14',
#  '9',
#  '15',
#  '41',
#  '55',
#  '-14',
#  '51',
#  '',
#  '',
#  '',
#  '',
#  '10',
#  '',
#  'Chelsea',
#  '',
#  '38',
#  '12',
#  '14',
#  '12',
#  '59',
#  '53',
#  '6',
#  '50',
#  '',
#  '',
#  '',
#  '',
#  '11',
#  '',
#  'Everton',
#  '',
#  '38',
#  '11',
#  '14',
#  '13',
#  '59',
#  '55',
#  '4',
#  '47',
#  '',
#  '',
#  '',
#  '',
#  '12',
#  '',
#  'Swansea City',
#  '',
#  '38',
#  '12',
#  '11',
#  '15',
#  '42',
#  '52',
#  '-10',
#  '47',
#  '',
#  '',
#  '',
#  '',
#  '13',
#  '',
#  'Watford',
#  '',
#  '38',
#  '12',
#  '9',
#  '17',
#  '40',
#  '50',
#  '-10',
#  '45',
#  '',
#  '',
#  '',
#  '',
#  '14',
#  '',
#  'West Bromwich Albion',
#  '',
#  '38',
#  '10',
#  '13',
#  '15',
#  '34',
#  '48',
#  '-14',
#  '43',
#  '',
#  '',
#  '',
#  '',
#  '15',
#  '',
#  'Crystal Palace',
#  '',
#  '38',
#  '11',
#  '9',
#  '18',
#  '39',
#  '51',
#  '-12',
#  '42',
#  '',
#  '',
#  '',
#  '',
#  '16',
#  '',
#  'Bournemouth',
#  '',
#  '38',
#  '11',
#  '9',
#  '18',
#  '45',
#  '67',
#  '-22',
#  '42',
#  '',
#  '',
#  '',
#  '',
#  '17',
#  '',
#  'Sunderland',
#  '',
#  '38',
#  '9',
#  '12',
#  '17',
#  '48',
#  '62',
#  '-14',
#  '39',
#  '',
#  '',
#  '',
#  '',
#  '18',
#  '',
#  'Newcastle United',
#  '',
#  '38',
#  '9',
#  '10',
#  '19',
#  '44',
#  '65',
#  '-21',
#  '37',
#  '',
#  '',
#  '',
#  '',
#  '19',
#  '',
#  'Norwich City',
#  '',
#  '38',
#  '9',
#  '7',
#  '22',
#  '39',
#  '67',
#  '-28',
#  '34',
#  '',
#  '',
#  '',
#  '',
#  '20',
#  '',
#  'Aston Villa',
#  '',
#  '38',
#  '3',
#  '8',
#  '27',
#  '27',
#  '76',
#  '-49',
#  '17',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# Almost there, we don't have html tags or line breaks (\n) anymore, only empty values in the string. Our last data cleaning step is to remove those.

# %%
cleantext3 = list(filter(lambda a: a != '', cleantext2))
print(cleantext3)
# Out:
# ['1', 'Leicester City', '38', '23', '12', '3', '68', '36', '32', '81', '2', 'Arsenal', '38', '20', '11', '7', '65', '36', '29', '71', '3', 'Tottenham Hotspur', '38', '19', '13', '6', '69', '35', '34', '70', '4', 'Manchester City', '38', '19', '9', '10', '71', '41', '30', '66', '5', 'Manchester United', '38', '19', '9', '10', '49', '35', '14', '66', '6', 'Southampton', '38', '18', '9', '11', '59', '41', '18', '63', '7', 'West Ham United', '38', '16', '14', '8', '65', '51', '14', '62', '8', 'Liverpool', '38', '16', '12', '10', '63', '50', '13', '60', '9', 'Stoke City', '38', '14', '9', '15', '41', '55', '-14', '51', '10', 'Chelsea', '38', '12', '14', '12', '59', '53', '6', '50', '11', 'Everton', '38', '11', '14', '13', '59', '55', '4', '47', '12', 'Swansea City', '38', '12', '11', '15', '42', '52', '-10', '47', '13', 'Watford', '38', '12', '9', '17', '40', '50', '-10', '45', '14', 'West Bromwich Albion', '38', '10', '13', '15', '34', '48', '-14', '43', '15', 'Crystal Palace', '38', '11', '9', '18', '39', '51', '-12', '42', '16', 'Bournemouth', '38', '11', '9', '18', '45', '67', '-22', '42', '17', 'Sunderland', '38', '9', '12', '17', '48', '62', '-14', '39', '18', 'Newcastle United', '38', '9', '10', '19', '44', '65', '-21', '37', '19', 'Norwich City', '38', '9', '7', '22', '39', '67', '-28', '34', '20', 'Aston Villa', '38', '3', '8', '27', '27', '76', '-49', '17']

# %% [markdown]
# Turning this string in a csv file is our last step in our web scraping. To such activity, we will use the csv library.
# We will write the header firstly and then rows for each club data.

# %%
headers = ['Position','Club','G','W','D','L','F','A','GD','PTS']
i = 0
with open('season1516.csv', 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)    
    wr.writerow(headers)
    while i < 20:
        wr.writerow(cleantext3[10*i:10*(i+1)])
        i = i + 1

# %%
df = pd.read_csv('season1516.csv')
df.head()
# Out:
#    Position               Club   G   W   D   L   F   A  GD  PTS
# 0         1     Leicester City  38  23  12   3  68  36  32   81
# 1         2            Arsenal  38  20  11   7  65  36  29   71
# 2         3  Tottenham Hotspur  38  19  13   6  69  35  34   70
# 3         4    Manchester City  38  19   9  10  71  41  30   66
# 4         5  Manchester United  38  19   9  10  49  35  14   66

# %% [markdown]
# ## How did they let us win? (EDA and Data Visualization)

# %% [markdown]
# Now it's time to crunch some data.<br/><br/>There is a famous Leicester chant and I'll share some part of it because is our hypothesis
#
# *...We play from the back and counter attack<br/>Champions of England,
# <br/>You made us sing that ...*<br/>
#
# * What make teams champions? Having a deadly attack or a solid defense? <br/>
# * How the Big Six (the six biggest teams of England) let Leicester take the silverplate home?

# %% [markdown]
# ### What make teams champions? Having a deadly attack or a solid defense?
